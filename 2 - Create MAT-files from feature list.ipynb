# %% [markdown]
# ## Create MAT -files from feature list for metabolite annotation ##
#
# MS-Finder can make a query on molecular features using .mat -files

# %%
from helpers import getExcel
import pandas as pd
import ipywidgets as widgets
import io
import os
import openpyxl

#import tkinter as tk
#from tkinter import filedialog
#root = tk.Tk()
#canvas1 = tk.Canvas(root, width = 300, height = 300, bg = 'lightsteelblue')
#canvas1.pack()

# %%
def fillfield(s):
    if ("pos" in s.lower()):
        return "positive"
    if ("neg" in s.lower()):
        return "negative"

# %%
def createmsts(df, workingfolder):
    export_path = os.path.join(workingfolder, "MAT")
    export_path2 = os.path.join(workingfolder, "MAT_ms2")
    if (not os.path.isdir(export_path)): 
        os.mkdir(export_path)
    if (not os.path.isdir(export_path2)): 
        os.mkdir(export_path2)        
    try:
        for row in df.itertuples(index=False, name="metabo"):
            if ("2M" in getattr(row, 'Adduct_type')):
                name = getattr(row, 'Feature_ID')
                f = open(f"{export_path2}\\{name}.mat", "w")
                f.write(f"NAME: {name}\n")
                f.write(f"PRECURSORMZ: {getattr(row, 'Average_Mz')}\n")
                f.write(f"PRECURSORTYPE: {getattr(row, 'Adduct_type')}\n")
                f.write(f"RETENTIONTIME: {getattr(row, 'Average_Rt_min_')}\n")
                f.write(f"IONMODE: {fillfield(getattr(row, 'Ion_type'))}\n")
                f.write("MSTYPE: MS1\n")
                ms1 = str(getattr(row, 'MS1_isotopic_spectrum'))
                ms = ms1.replace(":", "\t")
                m = ms.split(" ")
                f.write(f"Num Peaks: {len(m)}\n")
                for peak in m:
                    f.write(f"{peak}\n")
                msms = str(getattr(row, 'MS_MS_spectrum'))
                if (msms != "nan"):
                    msm = msms.replace(":", "\t")
                    mm = msm.split(" ")
                    f.write("MSTYPE: MS2\n")
                    f.write(f"Num Peaks: {len(mm)}\n")
                    for peak in mm:
                        f.write(f"{peak}\n")
                f.close()
            else:
                name = getattr(row, 'Feature_ID')
                f = open(f"{export_path}\\{name}.mat", "w")
                f.write(f"NAME: {name}\n")
                f.write(f"PRECURSORMZ: {getattr(row, 'Average_Mz')}\n")
                f.write(f"PRECURSORTYPE: {getattr(row, 'Adduct_type')}\n")
                f.write(f"IONMODE: {getattr(row, 'Ion_type')}\n")
                f.write("MSTYPE: MS1\n")
                ms1 = str(getattr(row, 'MS1_isotopic_spectrum'))
                ms = ms1.replace(":", "\t")
                m = ms.split(" ")
                f.write(f"Num Peaks: {len(m)}\n")
                for peak in m:
                    f.write(f"{peak}\n")
                msms = str(getattr(row, 'MS_MS_spectrum'))
                if (msms != "nan"):
                    msm = msms.replace(":", "\t")
                    mm = msm.split(" ")
                    f.write("MSTYPE: MS2\n")
                    f.write(f"Num Peaks: {len(mm)}\n")
                    for peak in mm:
                        f.write(f"{peak}\n")
                f.close()
    except:
        raise
    else:
        print("Files created")

# %% [markdown]
# ### Select the working folder, MAT-files will be created in an appropriate subfolder ###

# %%
workingfolder = "/"

# %% [markdown]
# ### Type the filename of the excel sheet containing the molecular features ###

# %%
filename = ".xlsx"

# %% [markdown]
# ### Upload the source excel file for molecular features and create pandas dataframe. ###

# %%
df = getExcel(os.path.join(workingfolder, filename), filterms2=False)

# %%
df
# Out:
#                   Feature_ID      Split Column Ion_type  Alignment_ID  \
# 0      RP_Neg_480_2148a7_575     RP_Neg     RP      Neg         10698
# 1     RP_Pos_480_2526a10_308     RP_Pos     RP      Pos         21299
# 2     RP_Pos_480_2719a10_426     RP_Pos     RP      Pos         21300
# 3      RP_Pos_480_2782a7_292     RP_Pos     RP      Pos         21302
# 4      RP_Pos_498_2803a4_555     RP_Pos     RP      Pos         22044
# 5      RP_Pos_498_2804a5_002     RP_Pos     RP      Pos         22045
# 6      RP_Pos_498_2821a10_42     RP_Pos     RP      Pos         22047
# 7     RP_Pos_498_2825a10_588     RP_Pos     RP      Pos         22048
# 8      RP_Pos_498_2884a7_565     RP_Pos     RP      Pos         22050
# 9      RP_Pos_498_2887a7_972     RP_Pos     RP      Pos         22051
# 10     RP_Pos_514_2834a7_311     RP_Pos     RP      Pos         22603
# 11     RP_Neg_514_2855a7_503     RP_Neg     RP      Neg         11459
# 12     RP_Neg_514_2855a8_726     RP_Neg     RP      Neg         11460
# 13     RP_Neg_514_2857a7_226     RP_Neg     RP      Neg         11461
# 14  HILIC_Neg_516_2045a6_415  HILIC_Neg  HILIC      Neg          3671
# 15     RP_Pos_516_2772a1_979     RP_Pos     RP      Pos         22650
# 16     RP_Neg_286_0763a3_876     RP_Neg     RP      Neg          4087
#
#     Average_Rt_min_  Average_Mz                Metabolite_name   Adduct_type  \
# 0             7.575   480.21481                        Unknown  [M+HCOOH-H]-
# 1            10.308   480.25262                        Unknown        [M+H]+
# 2            10.426   480.27191                        Unknown        [M+H]+
# 3             7.292   480.27817                        Unknown       [M+Na]+
# 4             4.555   498.28030                        Unknown  [M+CH3OH+H]+
# 5             5.002   498.28043                        Unknown        [M+H]+
# 6            10.420   498.28214                        Unknown        [M+H]+
# 7            10.588   498.28253                        Unknown        [M+H]+
# 8             7.565   498.28845       w/o MS2:Taurocholic acid    [M+ACN+H]+
# 9             7.972   498.28867       w/o MS2:Taurocholic acid        [M+H]+
# 10            7.311   514.28339                        Unknown  [M+CH3OH+H]+
# 11            7.503   514.28546  w/o MS2:NTBC Taurocholic Acid        [M-H]-
# 12            8.726   514.28546  w/o MS2:NTBC Taurocholic Acid        [M-H]-
# 13            7.226   514.28571  w/o MS2:NTBC Taurocholic Acid        [M-H]-
# 14            6.415   516.20453                        Unknown        [M-H]-
# 15            1.979   516.27716                        Unknown       [2M+H]+
# 16            3.876   286.07629                        Unknown        [M-H]-
#
#                                  Post_curation_result  ...      Mean_HCR  \
# 0                      adduct linked to 10435_[M+Cl]-  ...  4.774950e+04
# 1                                                 NaN  ...  4.142742e+04
# 2                                                 NaN  ...  4.414671e+05
# 3                       adduct linked to 21948_[M+K]+  ...  1.283130e+05
# 4   ion correlated with 13011; adduct linked to 67...  ...  2.517863e+05
# 5                                                 NaN  ...  4.125780e+05
# 6                                                 NaN  ...  1.429724e+05
# 7                      adduct linked to 22781_[M+Na]+  ...  2.448190e+06
# 8                       adduct linked to 20242_[M+H]+  ...  5.113647e+04
# 9                                                 NaN  ...  1.115009e+05
# 10                  adduct linked to 20645_[M-NH3+H]+  ...  5.845325e+05
# 11                                                NaN  ...  9.012741e+05
# 12                                                NaN  ...  8.826833e+04
# 13                                                NaN  ...  5.857963e+04
# 14                                                NaN  ...  1.116071e+06
# 15                       adduct linked to 7131_[M+H]+  ...  3.268856e+04
# 16                                                NaN  ...  2.657622e+04
#
#          Mean_LCR  Mean_HCR_minus_LCR  HCR_LCR_Lower_CI_95  \
# 0    51219.031413       -3.469528e+03        -2.572918e+04
# 1    40823.499124        6.039215e+02        -2.889688e+04
# 2    97206.108097        3.442610e+05        -1.083304e+05
# 3    41162.995030        8.714997e+04        -5.412562e+04
# 4   221780.978592        3.000529e+04        -1.404364e+04
# 5   392480.197480        2.009779e+04        -7.345431e+04
# 6    44352.068579        9.862031e+04        -1.705399e+04
# 7   659235.412139        1.788954e+06        -4.970681e+05
# 8   158696.625053       -1.075602e+05        -3.410141e+05
# 9    67411.445668        4.408950e+04        -8.409870e+04
# 10  756037.912578       -1.715054e+05        -1.066797e+06
# 11  185204.777716        7.160693e+05        -1.495052e+05
# 12   69096.653765        1.917167e+04        -8.220357e+04
# 13   11282.475206        4.729715e+04        -1.079647e+04
# 14  988254.607511        1.278160e+05        -1.816807e+05
# 15   26797.936489        5.890620e+03        -2.126711e+04
# 16  133036.934292       -1.064607e+05        -1.277872e+05
#
#    HCR_LCR_Upper_CI_95  HCR_LCR_t_test_P  HCR_LCR_t_test_P_FDR    min    mid  \
# 0         1.879013e+04          0.730335              0.909757  18780  18780
# 1         3.010472e+04          0.960512              0.988731  18780  18780
# 2         7.968524e+05          0.114820              0.613978  18780  18780
# 3         2.284256e+05          0.185526              0.637612  18780  18780
# 4         7.405422e+04          0.157346              0.624083  18780  18780
# 5         1.136499e+05          0.636845              0.869931  18780  18780
# 6         2.142946e+05          0.082401              0.611076  18780  18780
# 7         4.074977e+06          0.104436              0.612242  18780  18780
# 8         1.258938e+05          0.264710              0.690547  18780  18780
# 9         1.722777e+05          0.456378              0.783425  18780  18780
# 10        7.237858e+05          0.658192              0.879529  18780  18780
# 11        1.581644e+06          0.090433              0.611634  18780  18780
# 12        1.205469e+05          0.670692              0.883525  18780  18780
# 13        1.053908e+05          0.094384              0.611634  18780  18780
# 14        4.373127e+05          0.372531              0.741090  18780  18780
# 15        3.304835e+04          0.619452              0.861399  18780  18780
# 16       -8.513422e+04          0.000004              0.065888  18780  18780
#
#              max
# 0   18780.000000
# 1   18159.010000
# 2   16929.780000
# 3   16313.330000
# 4   18780.000000
# 5   18780.000000
# 6   18780.000000
# 7   18780.000000
# 8   18780.000000
# 9   16310.973333
# 10  18780.000000
# 11  18780.000000
# 12  18780.000000
# 13  18780.000000
# 14  18780.000000
# 15  18780.000000
# 16  18780.000000
#
# [17 rows x 62 columns]

# %% [markdown]
# ### Create MAT-files inside the assigned folder. ###

# %%
createmsts(df, workingfolder)
# Out:
# Files created

# %% [markdown]
# That should be it
